# %% [markdown]
# <a href="https://colab.research.google.com/github/NikolayKartaev/PYTHON/blob/main/Homework_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### **Задача 1.** Найдите, какая область центрального федерального округа имела наибольшую численность студентов вечерней формы обучения в 2015 году.

# %%
data = pd.read_csv('Homework_data.csv', sep = ";", encoding = 'cp1251')

# %%
newdata = data.iloc[2:19,:]

# %%
newdata = newdata[['Субъект РФ', 'Численность студентов очно-заочная (вечерняя) форма, человек, 2015']][newdata['Численность студентов очно-заочная (вечерняя) форма, человек, 2015'] == max(newdata['Численность студентов очно-заочная (вечерняя) форма, человек, 2015'])]

newdata
# Out:
#                Субъект РФ  \
# 11     Московская область
#
#     Численность студентов очно-заочная (вечерняя) форма, человек, 2015
# 11                                               4095

# %% [markdown]
# ### **Задача 2.** Постройте диаграмму с данными о численности студентов дневной формы обучения южного федерального округа за 2017 год.

# %%
newdata_2 = data.iloc[33:41,:][['Субъект РФ', 'Численность студентов, очная форма, человек, 2017']]

newdata_2

# %%
plot = sns.barplot(newdata_2, x = 'Численность студентов, очная форма, человек, 2017', y = 'Субъект РФ')
plot
# Out:
# <Axes: xlabel='Численность студентов, очная форма, человек, 2017', ylabel='Субъект РФ'>

# %% [markdown]
# ### **Задача 3**. Постройте диаграмму количества студентов заочной формы обучения за 2019 год по всем регионам, в которых общее количество студентов не превышает 10000 за данный год.

# %%
newdata_3 = data[data['Численность студентов, всего человек, 2019']<=10000]
newdata_3 = newdata_3[['Субъект РФ','Численность студентов заочная форма, человек, 2019','Численность студентов, всего человек, 2019']]

# %%
plot_2 = sns.barplot(newdata_3, x = 'Численность студентов заочная форма, человек, 2019', y = 'Субъект РФ')

plot_2
# Out:
# <Axes: xlabel='Численность студентов заочная форма, человек, 2019', ylabel='Субъект РФ'>
